# %%
import pandas as pd
import json

# %%
df = pd.read_json("cars.txt")

# %%
df['make'] == 'Ford'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1628    False
# 1629    False
# 1630    False
# 1631    False
# 1632    False
# Name: make, Length: 1633, dtype: bool

# %%
df.head(10)
# Out:
#             engine                               designer assembly  electric  \
# 0             None                                   None     None     False
# 1       [6.6, 7.0]                                   None     None     False
# 2  [7.0, 7.0, 7.5]                                   None     None     False
# 3       [7.5, 5.7]                                   None     None     False
# 4             None                                   None     None     False
# 5            [7.5]  Bill Mitchell (designer)Bill Mitchell       []     False
# 6            [7.5]  Bill Mitchell (designer)Bill Mitchell       []     False
# 7               []                                   None       []     False
# 8             None                                   None     None     False
# 9            [6.6]  Bill Mitchell (designer)Bill Mitchell       []     False
#
#        weight                                              width  \
# ...

# %%
df.columns
# Out:
# Index(['engine', 'designer', 'assembly', 'electric', 'weight', 'width',
#        'generation', 'make', 'modelyears', 'class', 'height', 'transmission',
#        'length', 'production', 'bodystlye', 'model', 'wheelbase', 'image',
#        'manufacturer'],
#       dtype='object')

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...

# %%
for index, row in df.iterrows():
    if (index, row['make'] is 'Ford'):
        print(index, row)
# Out:
# 0 engine                                                       None
# designer                                                     None
# assembly                                                     None
# electric                                                    False
# weight                                                       None
# width                                                        None
# generation                                          Buick Wildcat
# make                                                        Buick
# modelyears                                                   None
# class                                             [Full-size car]
# height                                                       None
# transmission                                                 None
# length                                                       None
# production                                             [19631970]
# ...

# %%
df.loc[df['make'] == 'Ford']
# Out:
#      engine    designer                                           assembly  \
# 828      []        None                                               None
# 829    None        None                                               None
# 830      []        None                                               None
# 831      []        None  [Struandale, Port Elizabeth, Silverton, Pretoria]
# 832      []  Henry Ford                                               None
# ...     ...         ...                                                ...
# 1089     []        None                                                 []
# 1090  [2.3]        None                                               None
# 1091     []        None                                                 []
# 1092   None        None                                                 []
# 1093     []        None                                                 []
#
# ...

# %%
df['modelyears'].dtypes
# Out:
# engine          object
# designer        object
# assembly        object
# electric          bool
# weight          object
# width           object
# generation      object
# make            object
# modelyears      object
# class           object
# height          object
# transmission    object
# length          object
# production      object
# bodystlye       object
# model           object
# wheelbase       object
# image           object
# manufacturer    object
# dtype: object

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...
