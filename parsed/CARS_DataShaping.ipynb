# %%
import pandas as pd
import json

# %%
df = pd.read_json("cars.txt")

# %%
df['make'] == 'Ford'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1628    False
# 1629    False
# 1630    False
# 1631    False
# 1632    False
# Name: make, Length: 1633, dtype: bool

# %%
df.head(10)
# Out:
#             engine                               designer assembly  electric  \
# 0             None                                   None     None     False
# 1       [6.6, 7.0]                                   None     None     False
# 2  [7.0, 7.0, 7.5]                                   None     None     False
# 3       [7.5, 5.7]                                   None     None     False
# 4             None                                   None     None     False
# 5            [7.5]  Bill Mitchell (designer)Bill Mitchell       []     False
# 6            [7.5]  Bill Mitchell (designer)Bill Mitchell       []     False
# 7               []                                   None       []     False
# 8             None                                   None     None     False
# 9            [6.6]  Bill Mitchell (designer)Bill Mitchell       []     False
#
#        weight                                              width  \
# ...

# %%
df.columns
# Out:
# Index(['engine', 'designer', 'assembly', 'electric', 'weight', 'width',
#        'generation', 'make', 'modelyears', 'class', 'height', 'transmission',
#        'length', 'production', 'bodystlye', 'model', 'wheelbase', 'image',
#        'manufacturer'],
#       dtype='object')

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...

# %%
for index, row in df.iterrows():
    len(row['modelyears'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-891d7afff704> in <module>
#       1 for index, row in df.iterrows():
# ----> 2     len(row['modelyears'])
#
# TypeError: object of type 'NoneType' has no len()

# %%
df.loc[df['modelyears'].str.len() == 8]
# Out:
# Empty DataFrame
# Columns: [engine, designer, assembly, electric, weight, width, generation, make, modelyears, class, height, transmission, length, production, bodystlye, model, wheelbase, image, manufacturer]
# Index: []

# %%
singlestring = df.loc[df['modelyears'].str.len() ==  8]

# %%
df.loc[type(df['modelyears'].values) == int]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-ee7c0ed55228> in <module>
# ----> 1 df.loc[type(df['modelyears'].values) == int]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
# ...

# %%
print(df['modelyears'].values.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-6991642aae60> in <module>
# ----> 1 print(df['modelyears'].values.dtypes)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dtypes'

# %%
singlestring
# Out:
#     engine designer assembly  electric  weight   width         generation  \
# 872     []     None     None     False  [2388]  [65.9]  Second generation
#
#      make modelyears class  height  \
# 872  Ford   19851988  None  [50.5]
#
#                                           transmission   length production  \
# 872  [4-speed ''Ford MTX transmission, MTX-I'' Manu...  [170.3]       None
#
#     bodystlye     model wheelbase            image manufacturer
# 872      None  Ford EXP    [94.2]  FordEXP1986.jpg         Ford

# %%
for index, row in singlestring.iterrows():
    print(type(row['modelyears'][0]))
#     if row['modelyears'][0].apply(str).contains(':', regex=False):
#         print((row['modelyears'][0]))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
df.loc[df['modelyears']]

# %%
df['modelyears']
# Out:
# 1633

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...

# %%
grouped = df.groupby(['make']).count().sort_values('model')

grouped
# Out:
#             engine  designer  assembly  electric  weight  width  generation  \
# make
# Hummer           3         1         3         3       2      3           3
# Tesla            0         5         5         7       5      6           6
# Saturn          11         3         9        14       5     10          14
# Packard         11         2         9        16       4      6          16
# Gmc             15         2        15        25       3      8          25
# Jeep            38        18        25        53      23     31          53
# Lincoln         52        26        44        63      30     41          63
# Plymouth        55         3        30        68      17     25          66
# Oldsmobile      70        24        57        87      29     44          87
# Mercury         64         2        46        89      20     43          89
# Pontiac         84        18        58       114      25     62         114
# ...

# %%
df
# Out:
#                engine                             designer  \
# 0                None                                 None
# 1          [6.6, 7.0]                                 None
# 2     [7.0, 7.0, 7.5]                                 None
# 3          [7.5, 5.7]                                 None
# 4                None                                 None
# ...               ...                                  ...
# 1628             None                 Franz von Holzhausen
# 1629             None                                 None
# 1630             None                 Franz von Holzhausen
# 1631             None                                 None
# 1632             None    Franz von Holzhausen  Sahm Jafari
#
#                                                assembly  electric  \
# 0                                                  None     False
# 1                                                  None     False
# ...
