# %%
import pandas as pd
import json

# %%
df = pd.read_json("cars.txt")

# %%
df['make'] == 'Ford'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15236    False
# 15237    False
# 15238    False
# 15239    False
# 15240    False
# Name: make, Length: 15241, dtype: bool

# %%
df.head(10)
# Out:
#        engine designer assembly  electric weight width        generation  \
# 0        None     None     None     False   None  None     Buick Wildcat
# 1        None     None     None     False   None  None     Buick Wildcat
# 2        None     None     None     False   None  None     Buick Wildcat
# 3        None     None     None     False   None  None     Buick Wildcat
# 4        None     None     None     False   None  None     Buick Wildcat
# 5        None     None     None     False   None  None     Buick Wildcat
# 6        None     None     None     False   None  None     Buick Wildcat
# 7        None     None     None     False   None  None     Buick Wildcat
# 8  [6.6, 7.0]     None     None     False   None  None  First Generation
# 9  [6.6, 7.0]     None     None     False   None  None  First Generation
#
#     make variant  modelyears            class height  \
# 0  Buick    None        1970  [Full-size car]   None
# 1  Buick    None        1970  [Full-size car]   None
# ...

# %%
df.columns
# Out:
# Index(['engine', 'designer', 'assembly', 'electric', 'weight', 'width',
#        'generation', 'make', 'variant', 'modelyears', 'class', 'height',
#        'transmission', 'length', 'production', 'bodystlye', 'model',
#        'wheelbase', 'image', 'manufacturer'],
#       dtype='object')

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...

# %%
for index, row in df.iterrows():
    print(len(str(row['modelyears'])))
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# ...

# %%
print(df['modelyears'].dtypes)
# Out:
# int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-78f01178437d> in <module>
# ----> 1 singlestring
#
# NameError: name 'singlestring' is not defined

# %%
for index, row in df.iterrows():
    if row['modelyears'] == 5198:
        print (row)
#     print(row['modelyears'])

# %%
df.loc[df['modelyears']]
# Out:
#           engine              designer assembly  electric  weight  \
# 1970          []  Irvin Rybicki (1983)       []     False    None
# 1970          []  Irvin Rybicki (1983)       []     False    None
# 1970          []  Irvin Rybicki (1983)       []     False    None
# 1970          []  Irvin Rybicki (1983)       []     False    None
# 1970          []  Irvin Rybicki (1983)       []     False    None
# ...          ...                   ...      ...       ...     ...
# 2012        None                  None     None     False    None
# 2012        None                  None     None     False    None
# 2021  [3.5, 3.9]                  None       []     False  [3345]
# 2021  [3.5, 3.9]                  None       []     False  [3345]
# 2020        None                  None     None     False    None
#
#                                          width         generation       make  \
# 1970  [{'198793': '68.2'}, {'199496': '68.5'}]  Chevrolet Corsica  Chevrolet
# ...

# %%
df['modelyears']
# Out:
# 0        1970
# 1        1970
# 2        1970
# 3        1970
# 4        1970
#          ...
# 12026    2012
# 12027    2012
# 12028    2021
# 12029    2021
# 12030    2020
# Name: modelyears, Length: 12031, dtype: int64

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...

# %%
grouped = df.groupby(['modelyears']).count().sort_values('modelyears')

grouped
# Out:
#             engine  designer  assembly  electric  weight  width  generation  \
# modelyears
# 1904             2         2         0         2       2      0           2
# 1905             2         2         0         2       2      0           2
# 1906             5         5         0         5       5      0           5
# 1907             7         0         7         7       0      0           7
# 1908             6         6         0         6       6      0           6
# ...            ...       ...       ...       ...     ...    ...         ...
# 2019           201        69        96       252      54     85         252
# 2020           650       267       716      1879     367    516        1827
# 2021             0         2         0         2       0      0           2
# 2022            11        11        11        11      11     11          11
# 4697             4         0         0         4       4      4           4
#
# ...

# %%
df
# Out:
#                engine                             designer  \
# 0                None                                 None
# 1          [6.6, 7.0]                                 None
# 2     [7.0, 7.0, 7.5]                                 None
# 3          [7.5, 5.7]                                 None
# 4                None                                 None
# ...               ...                                  ...
# 1628             None                 Franz von Holzhausen
# 1629             None                                 None
# 1630             None                 Franz von Holzhausen
# 1631             None                                 None
# 1632             None    Franz von Holzhausen  Sahm Jafari
#
#                                                assembly  electric  \
# 0                                                  None     False
# 1                                                  None     False
# ...
